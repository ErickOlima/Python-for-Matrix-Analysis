# %%
a=3
a
# Out:
# 3

# %%
import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = x ** 2 - 1/x

plt.plot(x, y)
plt.title('Plot of $x^2$')
plt.xlabel('x')
plt.ylabel('$x^2$')
plt.grid(True)
plt.show()
